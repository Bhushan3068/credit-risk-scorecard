# %%
import pandas as pd
df = pd.read_csv('../data/loan_raw.csv.gz')
print(df.shape)
# Out:
# C:\Users\91703\AppData\Local\Temp\ipykernel_24660\2687718265.py:2: DtypeWarning: Columns (0,19,49,59,118,129,130,131,134,135,136,139,145,146,147) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/loan_raw.csv.gz')
# (2260701, 151)
